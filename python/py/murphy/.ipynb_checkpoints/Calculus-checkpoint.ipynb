# %%
import numpy as np
from __future__ import division
from sympy import *
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
X = np.arange(-3, 4)
X
# Out:
# array([-3, -2, -1,  0,  1,  2,  3])

# %%
def f(x):
    return x**2 + 1

# %%
f(X)
# Out:
# array([10,  5,  2,  1,  2,  5, 10])

# %%
plt.scatter(X, f(X))
plt.show()

# %%
x = symbols('x')

plot(sin(x))
plt.show()
